# %%
import random

# %%
random.randint(1,10)
# Out:
# 8

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
ord('A')
# Out:
# 65

# %%
ord('V')
# Out:
# 86

# %%
'sejal'>'vedant'
# Out:
# False

# %%
my_string = "Python Programming is Fun!"

# %%
len(my_string)
# Out:
# 26

# %%
my_string.count("n")
# Out:
# 3

# %%
my_list = [3,8.5,2,11,6.7,9,4.2,7,10,5.5]

# %%
my_list
# Out:
# [3, 8.5, 2, 11, 6.7, 9, 4.2, 7, 10, 5.5]

# %%
result = sum(my_list)/len(my_list)

# %%
print(result)
# Out:
# 6.69

# %%
# single element stored in a tupel = (5,)

# %%
def loop():
    for i in range (1,5):
        print ("Hello")

# %%
loop()
# Out:
# Hello
# Hello
# Hello
# Hello

# %%
def add (a,b):
    c=a+b
    print (c)

# %%
add(3,4)
# Out:
# 7

# %%
def myfactorial(n):
    if n == 1:
        return 1
    else:
        return n * myfactorial(n - 1)

# %%
myfactorial(3)
# Out:
# 6

# %%
#map function returns the value which i want to convert into list
#map(function,itrable)
